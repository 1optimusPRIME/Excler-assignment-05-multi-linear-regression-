# %% [markdown]
# # Q1.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
data = pd.read_csv("ToyotaCorolla.csv",encoding='latin1')

# %%
data
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
data.corr()
# Out:
#                         Id     Price  Age_08_04  Mfg_Month  Mfg_Year  \
# Id                1.000000 -0.738250   0.906132   0.043742 -0.919523
# Price            -0.738250  1.000000  -0.876590  -0.018138  0.885159
# Age_08_04         0.906132 -0.876590   1.000000  -0.123255 -0.983661
# Mfg_Month         0.043742 -0.018138  -0.123255   1.000000 -0.057416
# Mfg_Year         -0.919523  0.885159  -0.983661  -0.057416  1.000000
# KM                0.273298 -0.569960   0.505672  -0.020630 -0.504974
# HP               -0.109375  0.314990  -0.156622  -0.039312  0.164697
# Met_Color        -0.079713  0.108905  -0.108150   0.030266  0.103310
# Automatic         0.066265  0.033081   0.031717   0.009146 -0.033567
# cc               -0.117704  0.126389  -0.098084   0.037387  0.091892
# Doors            -0.130207  0.185326  -0.148359  -0.012069  0.151442
# Cylinders              NaN       NaN        NaN        NaN       NaN
# Gears            -0.043343  0.063104  -0.005364  -0.013063  0.007766
# ...

# %%
toyota0=pd.concat([data.iloc[:,2:4],data.iloc[:,6:7],data.iloc[:,8:9],data.iloc[:,12:14],data.iloc[:,15:18]],axis=1)
toyota0
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
toyota1=toyota0.rename({'Age_08_04':'Age','cc':'CC','Quarterly_Tax':'QT'},axis=1)
toyota1
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1431   7500   69  20544   86  1300      3      5   69    1025
# 1432  10845   72  19000   86  1300      3      5   69    1015
# 1433   8500   71  17016   86  1300      3      5   69    1015
# 1434   7250   70  16916   86  1300      3      5   69    1015
# 1435   6950   76      1  110  1600      5      5   19    1114
#
# [1436 rows x 9 columns]

# %%
toyota1[toyota1.duplicated()]
# Out:
#      Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 113  24950    8  13253  116  2000      5      5  234    1320

# %%
toyota2=toyota1.drop_duplicates().reset_index(drop=True)

# %%
toyota2
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1430   7500   69  20544   86  1300      3      5   69    1025
# 1431  10845   72  19000   86  1300      3      5   69    1015
# 1432   8500   71  17016   86  1300      3      5   69    1015
# 1433   7250   70  16916   86  1300      3      5   69    1015
# 1434   6950   76      1  110  1600      5      5   19    1114
#
# [1435 rows x 9 columns]

# %%
toyota2.describe()
# Out:
#               Price          Age             KM           HP            CC  \
# count   1435.000000  1435.000000    1435.000000  1435.000000   1435.000000
# mean   10720.915679    55.980488   68571.782578   101.491986   1576.560976
# std     3608.732978    18.563312   37491.094553    14.981408    424.387533
# min     4350.000000     1.000000       1.000000    69.000000   1300.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.000000
# 50%     9900.000000    61.000000   63451.000000   110.000000   1600.000000
# 75%    11950.000000    70.000000   87041.500000   110.000000   1600.000000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.000000
#
#              Doors        Gears           QT       Weight
# count  1435.000000  1435.000000  1435.000000  1435.000000
# mean      4.032753     5.026481    87.020209  1072.287108
# std       0.952667     0.188575    40.959588    52.251882
# min       2.000000     3.000000    19.000000  1000.000000
# ...

# %%
toyota2.corr()
# Out:
#            Price       Age        KM        HP        CC     Doors     Gears  \
# Price   1.000000 -0.876273 -0.569420  0.314134  0.124375  0.183604  0.063831
# Age    -0.876273  1.000000  0.504575 -0.155293 -0.096549 -0.146929 -0.005629
# KM     -0.569420  0.504575  1.000000 -0.332904  0.103822 -0.035193  0.014890
# HP      0.314134 -0.155293 -0.332904  1.000000  0.035207  0.091803  0.209642
# CC      0.124375 -0.096549  0.103822  0.035207  1.000000  0.079254  0.014732
# Doors   0.183604 -0.146929 -0.035193  0.091803  0.079254  1.000000 -0.160101
# Gears   0.063831 -0.005629  0.014890  0.209642  0.014732 -0.160101  1.000000
# QT      0.211508 -0.193319  0.283312 -0.302287  0.305982  0.107353 -0.005125
# Weight  0.575869 -0.466484 -0.023969  0.087143  0.335077  0.301734  0.021238
#
#               QT    Weight
# Price   0.211508  0.575869
# Age    -0.193319 -0.466484
# KM      0.283312 -0.023969
# HP     -0.302287  0.087143
# CC      0.305982  0.335077
# Doors   0.107353  0.301734
# ...

# %%
sns.set_style(style='darkgrid')
sns.pairplot(toyota2)
plt.show()

# %%
model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=toyota1).fit()

# %%
model.params
# Out:
# Intercept   -5573.106358
# Age          -121.658402
# KM             -0.020817
# HP             31.680906
# CC             -0.121100
# Doors          -1.616641
# Gears         594.319936
# QT              3.949081
# Weight         16.958632
# dtype: float64

# %%
model.tvalues , np.round (model.pvalues,5)
# Out:
# (Intercept    -3.948666
#  Age         -46.511852
#  KM          -16.621622
#  HP           11.241018
#  CC           -1.344222
#  Doors        -0.040410
#  Gears         3.016007
#  QT            3.014535
#  Weight       15.879803
#  dtype: float64,
#  Intercept    0.00008
#  Age          0.00000
#  KM           0.00000
#  HP           0.00000
#  CC           0.17909
#  Doors        0.96777
#  Gears        0.00261
#  QT           0.00262
#  Weight       0.00000
#  dtype: float64)

# %%
model.rsquared , model.rsquared_adj
# Out:
# (0.8637627463428191, 0.8629989775766962)

# %%
A1=smf.ols('Price~CC',data=toyota2).fit()
A1.tvalues , A1.pvalues
# Out:
# (Intercept    24.879592
#  CC            4.745039
#  dtype: float64,
#  Intercept    7.236022e-114
#  CC            2.292856e-06
#  dtype: float64)

# %%
A2=smf.ols('Price~Doors',data=toyota2).fit()
A2.tvalues , A2.pvalues
# Out:
# (Intercept    19.421546
#  Doors         7.070520
#  dtype: float64,
#  Intercept    8.976407e-75
#  Doors        2.404166e-12
#  dtype: float64)

# %%
A3=smf.ols('Price~CC+Doors',data=toyota2).fit()
A3.tvalues , A3.pvalues
# Out:
# (Intercept    12.786341
#  CC            4.268006
#  Doors         6.752236
#  dtype: float64,
#  Intercept    1.580945e-35
#  CC           2.101878e-05
#  Doors        2.109558e-11
#  dtype: float64)

# %%
sm.qqplot(model.resid,line='q')
plt.title("normal q-q plot of residuals")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
list(np.where(model.resid>6000))
# Out:
# [array([147, 523], dtype=int64)]

# %%
list(np.where(model.resid<-6000))
# Out:
# [array([221, 601, 960], dtype=int64)]

# %%
def standard_values(vals) : return (vals-vals.mean())/vals.std()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Age',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([7.23682667e-03, 3.96793393e-03, 5.46476784e-03, ...,
#        8.44762355e-07, 6.97878368e-04, 1.08627724e-02])

# %%
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(toyota1)),np.round(c,3))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
np.argmax(c), np.max(c)
# Out:
# (80, 79.52010624139086)

# %%
k=toyota2.shape[1]
n=toyota2.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.020905923344947737

# %%
toyota2[toyota2.index.isin([80])]
# Out:
#     Price  Age     KM   HP     CC  Doors  Gears   QT  Weight
# 80  18950   25  20019  110  16000      5      5  100    1180

# %%
toyota_n=toyota2.copy()
toyota_n
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1430   7500   69  20544   86  1300      3      5   69    1025
# 1431  10845   72  19000   86  1300      3      5   69    1015
# 1432   8500   71  17016   86  1300      3      5   69    1015
# 1433   7250   70  16916   86  1300      3      5   69    1015
# 1434   6950   76      1  110  1600      5      5   19    1114
#
# [1435 rows x 9 columns]

# %%
toyota3=toyota_n.drop(toyota_n.index[[80]],axis=0).reset_index(drop=True)
toyota3
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1429   7500   69  20544   86  1300      3      5   69    1025
# 1430  10845   72  19000   86  1300      3      5   69    1015
# 1431   8500   71  17016   86  1300      3      5   69    1015
# 1432   7250   70  16916   86  1300      3      5   69    1015
# 1433   6950   76      1  110  1600      5      5   19    1114
#
# [1434 rows x 9 columns]

# %%
datap=pd.DataFrame({'Age':12,'KM':40000,'HP':80,'CC':1300,'Doors':4,"Gears":5,"QT":69,"Weight":1012},index=[0])

# %%
datap
# Out:
#    Age     KM  HP    CC  Doors  Gears  QT  Weight
# 0   12  40000  80  1300      4      5  69    1012

# %%
 while np.max(c)>0.5 :
    model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=toyota3).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    toyota3=toyota3.drop(toyota3.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    toyota3
else:
    final_model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=toyota3).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.8882395145171204

# %%
if np.max(c)>0.5:
    model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=toyota3).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    toyota3=toyota3.drop(toyota3.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    toyota3 
elif np.max(c)<0.5:
    final_model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=toyota3).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.8882395145171204

# %%
final_model.rsquared
# Out:
# 0.8882395145171204

# %%
toyota3
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1426   7500   69  20544   86  1300      3      5   69    1025
# 1427  10845   72  19000   86  1300      3      5   69    1015
# 1428   8500   71  17016   86  1300      3      5   69    1015
# 1429   7250   70  16916   86  1300      3      5   69    1015
# 1430   6950   76      1  110  1600      5      5   19    1114
#
# [1431 rows x 9 columns]

# %%
final_model.predict(datap)
# Out:
# 0    14341.570181
# dtype: float64

# %%
predict_y=final_model.predict(toyota3)
predict_y.head()
# Out:
# 0    16345.352610
# 1    15886.635544
# 2    16328.224968
# 3    15996.318854
# 4    15883.424182
# dtype: float64

# %% [markdown]
# # Q2.

# %%
from statsmodels.graphics.regressionplots import influence_plot

# %%
data_q2=pd.read_csv("50_Startups.csv")

# %%
data_q2.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data_q2.info(())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
data1=data_q2.rename({'R&D Spend':'RDS','Administration':'ADMS','Marketing Spend':'MKTS'},axis=1)
data1.head()
# Out:
#          RDS       ADMS       MKTS       State     Profit
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
data1.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
data1.describe()
# Out:
#                  RDS           ADMS           MKTS         Profit
# count      50.000000      50.000000      50.000000      50.000000
# mean    73721.615600  121344.639600  211025.097800  112012.639200
# std     45902.256482   28017.802755  122290.310726   40306.180338
# min         0.000000   51283.140000       0.000000   14681.400000
# 25%     39936.370000  103730.875000  129300.132500   90138.902500
# 50%     73051.080000  122699.795000  212716.240000  107978.190000
# 75%    101602.800000  144842.180000  299469.085000  139765.977500
# max    165349.200000  182645.560000  471784.100000  192261.830000

# %%
data1.corr()
# Out:
#              RDS      ADMS      MKTS    Profit
# RDS     1.000000  0.241955  0.724248  0.972900
# ADMS    0.241955  1.000000 -0.032154  0.200717
# MKTS    0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %%
sns.set_style(style='darkgrid')
sns.pairplot(data1)

# %%
model=smf.ols("Profit~RDS+ADMS+MKTS",data=data1).fit()

# %%
model.params
# Out:
# Intercept    50122.192990
# RDS              0.805715
# ADMS            -0.026816
# MKTS             0.027228
# dtype: float64

# %%
model.tvalues , model.pvalues
# Out:
# (Intercept     7.626218
#  RDS          17.846374
#  ADMS         -0.525507
#  MKTS          1.655077
#  dtype: float64,
#  Intercept    1.057379e-09
#  RDS          2.634968e-22
#  ADMS         6.017551e-01
#  MKTS         1.047168e-01
#  dtype: float64)

# %%
model.rsquared , model.rsquared_adj
# Out:
# (0.9507459940683246, 0.9475337762901719)

# %%
A1=smf.ols("Profit~ADMS",data=data1).fit()
A1.tvalues , A1.pvalues
# Out:
# (Intercept    3.040044
#  ADMS         1.419493
#  dtype: float64,
#  Intercept    0.003824
#  ADMS         0.162217
#  dtype: float64)

# %%
A2=smf.ols("Profit~MKTS",data=data1).fit()
A2.tvalues , A2.pvalues
# Out:
# (Intercept    7.808356
#  MKTS         7.802657
#  dtype: float64,
#  Intercept    4.294735e-10
#  MKTS         4.381073e-10
#  dtype: float64)

# %%
A3=smf.ols("Profit~ADMS+MKTS",data=data1).fit()
A3.tvalues , A3.pvalues
# Out:
# (Intercept    1.142741
#  ADMS         2.467779
#  MKTS         8.281039
#  dtype: float64,
#  Intercept    2.589341e-01
#  ADMS         1.729198e-02
#  MKTS         9.727245e-11
#  dtype: float64)

# %%
rsqu=smf.ols("RDS~ADMS+MKTS",data=data1).fit().rsquared
vif_r=1/(1-rsqu)

rsqu1=smf.ols("ADMS~RDS+MKTS",data=data1).fit().rsquared
vif_a=1/(1-rsqu1)

rsqu2=smf.ols("MKTS~RDS+ADMS",data=data1).fit().rsquared
vif_m=1/(1-rsqu2)

# Putting the values in Dataframe format
d1={'Variables':['RDS','ADMS','MKTS'],'Vif':[rsqu,rsqu1,rsqu2]}
Vif_df=pd.DataFrame(d1)
Vif_df
# Out:
#   Variables       Vif
# 0       RDS  0.594962
# 1      ADMS  0.149002
# 2      MKTS  0.570220

# %%
sm.qqplot(model.resid,line='q')
plt.show()

# %%
list(np.where(model.resid<-30000))
# Out:
# [array([49], dtype=int64)]

# %%
def standard_values(vals) : return (vals-vals.mean())/vals.std()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'RDS',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'ADMS',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'MKTS',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(data1)),np.round(c,5))
plt.ylabel('cook distence')
plt.show()

# %%
np.argmax(c), np.max(c)
# Out:
# (49, 0.2880822927543264)

# %%
influence_plot(model)
plt.show()

# %%
a=data1.shape[1]
b=data1.shape[0]
leverage_cutoff =(3*(k+1))/n
leverage_cutoff
# Out:
# 0.020905923344947737

# %%
data1[data1.index.isin([49])]
# Out:
#     RDS      ADMS      MKTS       State   Profit
# 49  0.0  116983.8  45173.06  California  14681.4

# %%
data_n=data1.drop(data1.index[[49]],axis=0).reset_index(drop=True)
data_n.head()
# Out:
#          RDS       ADMS       MKTS       State     Profit
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
while np.max(c)>0.5 :
    model=smf.ols("Profit~RDS+ADMS+MKTS",data=data_n).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    data_n=data_n.drop(data_n.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    data_n
else:
    final_model=smf.ols("Profit~RDS+ADMS+MKTS",data=data_n).fit()
    final_model.rsquared , final_model.aic
    print("accuracy improved ",final_model.rsquared)
# Out:
# accuracy improved  0.9613162435129847

# %%
final_model.rsquared
# Out:
# 0.9613162435129847

# %%
data_n
# Out:
#           RDS       ADMS       MKTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
pred=pd.DataFrame({"RDS":70000,"ADMS":90000,"MKTS":140000},index=[0])
pred
# Out:
#      RDS   ADMS    MKTS
# 0  70000  90000  140000

# %%
final_model.predict(pred)
# Out:
# 0    108727.154753
# dtype: float64

# %%
ypred=final_model.predict(data_n)
ypred
# Out:
# 0     190716.676999
# 1     187537.122227
# 2     180575.526396
# 3     172461.144642
# 4     170863.486721
# 5     162582.583177
# 6     157741.338633
# 7     159347.735318
# 8     151328.826941
# 9     154236.846778
# 10    135507.792682
# 11    135472.855621
# 12    129355.599449
# 13    127780.129139
# 14    149295.404796
# 15    145937.941975
# 16    117437.627921
# 17    130408.626295
# 18    129129.234457
# 19    116641.003121
# 20    117097.731866
# 21    117911.019038
# 22    115248.217796
# 23    110603.139045
# 24    114051.073877
# 25    103398.054385
# 26    111547.638935
# 27    114916.165026
# 28    103027.229434
# 29    103057.621761
# 30    100656.410227
# 31     99088.213693
# 32    100325.741335
# 33     98962.303136
# 34     90552.307809
# 35     91709.288672
# 36     77080.554255
# 37     90722.503244
# 38     71433.021956
# 39     85147.375646
# 40     76625.510303
# 41     76492.145175
# 42     72492.394974
# 43     62592.049718
# 44     67025.731107
# ...

# %%
d2={'Prep_Models':['Model','Final_Model'],'Rsquared':[model.rsquared,final_model.rsquared]}
table=pd.DataFrame(d2)
table
# Out:
#    Prep_Models  Rsquared
# 0        Model  0.950746
# 1  Final_Model  0.961316
